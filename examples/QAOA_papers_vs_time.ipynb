# %% [markdown]
# # Methodology
#
# Search Google Scholar for "quantum approximate optimization algorithm" and set year range to be the exact year

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,3))

years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
papers = [1, 5, 13, 45, 94, 197, 453, 582]

labels = [str(x) for x in years]
labels[-1] = '2021\n (10 months)'

plt.plot(years, papers, marker='o', c=(122/256,184/256,0))
plt.xlabel('Year')
plt.xticks(years, labels)
plt.ylabel('Number of papers')
plt.tight_layout()
plt.savefig('qaoa_papers.pdf')
